# %% [markdown]
# ### Problem 1
#
# Write a program that:
#
# 1. Asks the user for their `name`, `age`, and `favorite number`.
# 1. Stores these values in variables.
# 1. Prints a message like:
#
# `"Hello, [Name]! You are [Age] years old, and your favorite number is [Number]."`
#
#
# ----
#
# Example input :
#
# `John`
#
# `32`
#
# `7`
#
# Expected output:
#
# `Hello, John! You are 32 years old, and your favorite number is 7.`

# %%
# write your code here

# %% [markdown]
# ### Problem 2
#
# write a program that takes the `width` and `height` of a rectangle as input, then calculates the area of the rectangle using the formula :
#
# <center>$Area = Width \times Height$</center>
#
# ---
#
# Example input :
#
# `3`
#
# `2`
#
# Expected output:
#
# `6`
#
# You can see the rectangle from the example in the image bellow :
#
# ![image.png](attachment:38180b15-add5-4736-be59-dd364770aa10.png)

# %%
# write your code here

# %% [markdown]
# ### Problem 3
#
# Write a program that takes the user's current age and tells them the year of their birth. This is the formula:
#
# <center>$BirthYear = Current\hspace{0.1cm}Year - Age$</center>
#
# ----
#
# Example input :
#
# `27`
#
# Expected output:
#
# `1997`
#
# **Example Explanation** :
#
# Assuming current year is `2024`, then the formula would be `2024-27=1997`.

# %%
# write your code here

# %% [markdown]
# ### Problem 4
#
# Write a program that takes a person's `hours worked` in a month and `hourly rate` and calculates the person's salary based on them. Finally, `10%` of the person's salary is deducted for `tax` and the final salary is calculated. Here is the formula :
#
# <center>$Salary = (hourly\hspace{0.1cm}rate * hours\hspace{0.1cm}worked) \times 0.9$</center>
#
# -----
#
# Example input :
#
# _hourly rate_ = `15`
#
# _hours worked_ = `180`
#
# Expected output :
#
# `2430`
#
# **Example explanation** :
#
# According to the formula the salary would be calculated in this way :
#
# <center>$Salary = (15 \times 180) \times 0.9 = 2430$</center>

# %%
# write your code here

# %% [markdown]
# ### Problem 5
#
# Write a program that:
#
# 1. Asks the user to enter the three sides of a triangle.
#
# 2. Calculates the perimeter using the formula:
#
# <center> $Perimeter=a+b+c$</center>
#
# where `a`, `b`, and `c` are the sides of the triangle.
#
# 3. Prints the perimeter.
#
# ------
#
# Example input :
#
# `3`
#
# `4`
#
# `5`
#
# Expected output :
#
# `12`
#
# ![image.png](attachment:d29fc21c-3ac2-44d4-84a0-812ce47f25c0.png)

# %%
# write your code here

# %% [markdown]
# ### Problem 6
#
# Write a program that:
#
# 1. Asks the user for their weight (in kilograms) and height (in meters).
# 2. Calculates their Body Mass Index (BMI) using the formula:
#
# <center>$BMI=\dfrac{Weight}{Height^2}$</center>
#
# 3. Prints the result in a clear sentence, e.g.:
# `"Your BMI is [the value of BMI]."`
#
# ----
# Example input :
#
# _weight (kg)_ = `80`
#
# _height (m)_ = `1.75`
#
# Expected ouput:
#
# `26.122`
#
# **Example Explanation** :
#
# <center>$BMI = \dfrac{80}{1.75\times1.75} = 26.122$</center>

# %%
# write your code here

# %% [markdown]
# ### Problem 7
#
# Write a program that:
#
# 1. Asks the user to input the distance traveled (in kilometers) and the time taken (in hours).
# 2. Calculates the average speed using the formula:
#
# <center>$Speed=\frac{Distance}{Time}$</center>
#
# 3. Prints the calculated speed.
#
# ---
# example input :
#
# _distance (km)_ = `93`
#
# _time (h)_ = `1.5`
#
# Expected output:
#
# `62`
#
# **Example Explanation** :
#
# <center>$Speed = \frac{93}{1.5} = 62$</center>

# %%
# write your code here

# %% [markdown]
# ### Problem 8
#
# Write a program that:
#
# 1. Asks the user for the radius of a circle.
# 2. Calculates the area using the formula:
# <center>$Area = \pi \times Radius^2$</center>
#
# 3. Prints the result (use `3.14` for $\pi$).
# ----
#
# example input :
#
# `3`
#
# Expected output:
#
# `28.26`
#
# **Example Explanation** :
#
# <center>$Area = 3.14 \times 3 \times 3 = 28.26$</center>

# %%
# write your code here

# %% [markdown]
# ### Problem 9
#
# Write a program that:
#
# 1. Asks the user for three numbers.
# 2. Calculates the average using the formula:
#
# <center>$Average= \frac{Number1+Number2+Number3}{3}$</center>
#
# 3. Prints the average in a full sentence, e.g.:
# `"The average of the three numbers is [Real Average]."`
# ----
#
# example input :
#
# _number1_ = `3`
#
# _number2_ = `4`
#
# _number3_ = `8`
#
# Expected output:
#
# `5`
#
# **Example Explanation** :
#
# <center>$Average = \frac{3 + 4 + 5}{3} = \frac{15}{3} = 5$</center>

# %%
# write your code here
